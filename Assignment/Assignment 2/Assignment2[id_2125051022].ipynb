# %% [markdown]
# Safin Ahamed Sajid
# ID :2125051022

# %%
from google.colab import drive
drive.mount('/content/drive') # Mounting to /content/drive
# Out:
# Mounted at /content/drive

# %%
from google.colab import files
import cv2
from PIL import Image
import matplotlib.pyplot as plt
import urllib.request
import numpy as np

# %%
# Step 1: Provide the URL of the image
image_url = 'https://i.ytimg.com/vi/SUCBN63ZoYA/hq720.jpg?sqp=-oaymwEhCK4FEIIDSFryq4qpAxMIARUAAAAAGAElAADIQj0AgKJD&rs=AOn4CLBczLtjt96UZej7XyXKGEg7R5zNgA'  # Replace with the actual URL

# %%
# Step 2: Download the image using urllib
with urllib.request.urlopen(image_url) as response:
    img_array = np.asarray(bytearray(response.read()), dtype=np.uint8)  # Convert to NumPy array

# %%
# Step 3: Decode the image (convert it into OpenCV format)
img = cv2.imdecode(img_array, cv2.IMREAD_COLOR)  # Decode as a color image (BGR format)

# %%
# Step 4: Convert BGR to RGB for correct display
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
# Step 5: Display the image using Matplotlib
plt.imshow(img_rgb)
plt.axis('off')  # Remove axes for cleaner display
plt.title("Image from URL")
plt.show()

# %%
height = img.shape[0]
width = img.shape[1]

print(height,width)
# Out:
# 386 686

# %%
img_crop=img_rgb[0:400,0:500]

plt.imshow(img_crop)
plt.axis('off')  # Remove axes for cleaner display
plt.title("Cropped Image")
plt.show()

# %%
plt.imshow(img_rgb)
plt.axis('off')  # Remove axes for cleaner display
plt.title("Real Image")
plt.show()

# %%
# Step 1: Compute center coordinates
center_x, center_y = width // 2, height // 2

# Step 2: Define crop boundaries (100x100 pixels)
start_x, end_x = center_x - 50, center_x + 50
start_y, end_y = center_y - 50, center_y + 50

# Step 3: Crop the region
center_crop = img_rgb[start_y:end_y, start_x:end_x]

# Step 4: Display the cropped region
plt.figure(figsize=(4, 4))
plt.imshow(center_crop)
plt.axis('off')  # Hide axes for clarity
plt.title("100x100 Center Crop")
plt.show()

# %%
img_flip=cv2.flip(img_crop,-1)  #flip horizontally and vertically

plt.imshow(img_flip)
plt.axis('off')  # Remove axes for cleaner display
plt.title("Cropped Image")
plt.show()

# %%
img_resize=cv2.resize(img_rgb,(500,500)) #(width,height)

# %%
plt.imshow(img_rgb)
plt.axis('off')  # Remove axes for cleaner display
plt.title("Real Image")
plt.show()

# %%
plt.imshow(img_resize)
plt.axis('off')  # Remove axes for cleaner display
plt.title("Resized Image")
plt.show()

# %%
img_resize=cv2.resize(img_rgb,(256,256))

# %%
plt.imshow(img_rgb)
plt.axis('off')  # Remove axes for cleaner display
plt.title("Real Image")
plt.show()

# %%
plt.imshow(img_resize)
plt.axis('off')  # Remove axes for cleaner display
plt.title("Resized Image")
plt.show()

# %%
img_rotate = cv2.rotate(img_resize, cv2.ROTATE_180)

# %%
plt.imshow(img_rotate)
plt.axis('off')
plt.title("Rotated 180°")
plt.show()

# %%
img_flip_vertical = cv2.flip(img_rgb, 0)

# %%
plt.imshow(img_flip_vertical)
plt.axis('off')
plt.title("Vertically Flipped")
plt.show()

# %%
plt.figure(figsize=(10, 5))

plt.subplot(1, 4, 1)
plt.imshow(img_rgb)
plt.axis('off')
plt.title("Original Image")

plt.subplot(1, 4, 2)
plt.imshow(img_resize)
plt.axis('off')
plt.title("Resized (256x256)")

plt.subplot(1, 4, 3)
plt.imshow(img_rotate)
plt.axis('off')
plt.title("Rotated 180°")

plt.subplot(1, 4, 4)
plt.imshow(img_flip_vertical)
plt.axis('off')
plt.title("Vertically Flipped")

plt.tight_layout()
plt.show()
